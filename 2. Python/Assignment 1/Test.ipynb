# %%
print(True + True)
# Out:
# 2

# %%
a = [1,2,3]
b = a
b.append(4)
print(a)
# Out:
# [1, 2, 3, 4]

# %%
print(bool(""))
# Out:
# False

# %%
print(type (None))
# Out:
# <class 'NoneType'>

# %%
print( 5 == 5.0)
# Out:
# True
