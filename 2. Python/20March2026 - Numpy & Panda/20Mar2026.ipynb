# %% [markdown]
# Panda Library
# ================

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Purpose :
#
# 1. Data Analysis
# 2. Data Manipulation
# 3. Data Cleaning
# 4. Prepare Structured Data
