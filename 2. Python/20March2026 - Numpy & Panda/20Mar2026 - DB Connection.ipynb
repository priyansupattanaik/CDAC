# %% [markdown]
# **DATABASE CONNECTION**
# ---------------------------
# CRUD: INSERT, SELECT, UPDATE, DELETE
#
# FRONTEND:
#
# BACKEND:
# CRUD: INSERT, SELECT, UPDATE, DELETE

# %% [markdown]
# Import Libraries:
#
# import mysql.connector
#
# COnnection String:
#
# conn = mysql.connector.connect(
#     host="localhost",
#     user="root",
#     password="brucewayne",
#     database="test"
# )

# %% [markdown]
# Steps to create connections:
# -------------------------------
# Step 1: Create connection with MySQL
# Step 2: Check connection
# Step 3: Close connection

# %% [markdown]
# Steps to create connections: create database
# -------------------------------------------------
# Step 1: Create connection with MySQL
# Step 2: Create cursor object
# Step 3: SQL query to create table in database
# Step 4: Execute query
# Step 5: Close connection
